# %%
# !pip uninstall keras
# !pip install keras==2.11.0

# %%
pip install transformers[torch] -U
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers[torch] in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (4.32.1)
# Collecting transformers[torch]
#   Obtaining dependency information for transformers[torch] from https://files.pythonhosted.org/packages/75/d5/294a09a62bdd88da9a1007a341d4f8fbfc43be520c101e6afb526000e9f4/transformers-4.46.1-py3-none-any.whl.metadata
#   Downloading transformers-4.46.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 834.7 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: filelock in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from transformers[torch]) (3.9.0)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers[torch])
#   Obtaining dependency information for huggingface-hub<1.0,>=0.23.2 from https://files.pythonhosted.org/packages/60/bf/cea0b9720c32fa01b0c4ec4b16b9f4ae34ca106b202ebbae9f03ab98cd8f/huggingface_hub-0.26.2-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from transformers[torch]) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from transformers[torch]) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from transformers[torch]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from transformers[torch]) (2022.7.9)
# Requirement already satisfied: requests in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from transformers[torch]) (2.31.0)
# Collecting safetensors>=0.4.1 (from transformers[torch])
#   Obtaining dependency information for safetensors>=0.4.1 from https://files.pythonhosted.org/packages/e6/ee/69e498a892f208bd1da4104d4b9be887f8611bf4942144718b6738482250/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers[torch])
#   Obtaining dependency information for tokenizers<0.21,>=0.20 from https://files.pythonhosted.org/packages/09/6c/1b573998fe3f0e18ac5d434e43966de2d225d6837f099ce0df7df4274c87/tokenizers-0.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tokenizers-0.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from transformers[torch]) (4.65.0)
# Collecting accelerate>=0.26.0 (from transformers[torch])
#   Obtaining dependency information for accelerate>=0.26.0 from https://files.pythonhosted.org/packages/2c/92/48aec3736ca778ffe5fa68e19e3c18917cba4de43fa46fe6176cccafe267/accelerate-1.0.1-py3-none-any.whl.metadata
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: torch in /home/dbhatka/.local/lib/python3.11/site-packages (from transformers[torch]) (2.4.1)
# Requirement already satisfied: psutil in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from accelerate>=0.26.0->transformers[torch]) (5.9.0)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.23.2->transformers[torch])
#   Obtaining dependency information for fsspec>=2023.5.0 from https://files.pythonhosted.org/packages/c6/b2/454d6e7f0158951d8a78c2e1eb4f69ae81beb8dca5fee9809c6c99e9d0d0/fsspec-2024.10.0-py3-none-any.whl.metadata
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dbhatka/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (4.12.2)
# Requirement already satisfied: sympy in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from torch->transformers[torch]) (1.11.1)
# Requirement already satisfied: networkx in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from torch->transformers[torch]) (3.1)
# Requirement already satisfied: jinja2 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from torch->transformers[torch]) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/dbhatka/.local/lib/python3.11/site-packages (from torch->transformers[torch]) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/dbhatka/.local/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.6.68)
# Requirement already satisfied: charset-normalizer<4,>=2 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from requests->transformers[torch]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from requests->transformers[torch]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from requests->transformers[torch]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from requests->transformers[torch]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from jinja2->torch->transformers[torch]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.9/330.9 kB 5.1 MB/s eta 0:00:00a 0:00:01
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 14.6 MB/s eta 0:00:00
# Downloading safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 kB 27.5 MB/s eta 0:00:00
# Downloading tokenizers-0.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 53.8 MB/s eta 0:00:00a 0:00:01
# Downloading transformers-4.46.1-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 78.4 MB/s eta 0:00:00:00:010:01
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: safetensors, fsspec, huggingface-hub, tokenizers, transformers, accelerate
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.10.0 which is incompatible.
# Successfully installed accelerate-1.0.1 fsspec-2024.10.0 huggingface-hub-0.26.2 safetensors-0.4.5 tokenizers-0.20.1 transformers-4.46.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import torch
from transformers import BertTokenizer, BertForQuestionAnswering, Trainer, TrainingArguments, default_data_collator
from datasets import Dataset

with open("spoken_train-v1.1.json", "r") as f:
    data = json.load(f)

# Preparing data for Hugging Face datasets
qa_pairs = []
for article in data["data"]:
    for paragraph in article["paragraphs"]:
        context = paragraph["context"]
        for qa in paragraph["qas"]:
            question = qa["question"]
            answer_text = qa["answers"][0]["text"]
            answer_start = qa["answers"][0]["answer_start"]
            qa_pairs.append({
                "context": context,
                "question": question,
                "answers": {
                    "text": [answer_text],
                    "answer_start": [answer_start]
                }
            })

# converting to Hugging Face Dataset
dataset = Dataset.from_list(qa_pairs)
train_test_split = dataset.train_test_split(test_size=0.1)
train_dataset = train_test_split["train"]
test_dataset = train_test_split["test"]

# # Initializes tokenizer and model
# tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# model = BertForQuestionAnswering.from_pretrained("bert-base-uncased")

# %%
from transformers import BertTokenizerFast, BertForQuestionAnswering

# Initializes the fast tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")
model = BertForQuestionAnswering.from_pretrained("bert-base-uncased")
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def preprocess(examples):
    questions = examples["question"]
    contexts = examples["context"]
    inputs = tokenizer(
        questions,
        contexts,
        max_length=512,
        truncation="only_second",
        stride=128,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length"
    )

    offset_mapping = inputs.pop("offset_mapping")
    start_positions = []
    end_positions = []

    for i, offsets in enumerate(offset_mapping):
        if i >= len(examples["answers"]):
            start_positions.append(0)
            end_positions.append(0)
            continue
        
        if len(examples["answers"][i]["answer_start"]) == 0:
            start_positions.append(0)
            end_positions.append(0)
            continue

        answer_start = examples["answers"][i]["answer_start"][0]
        answer_text = examples["answers"][i]["text"][0]
        answer_end = answer_start + len(answer_text)

        start_position = end_position = 0
        for j, (start, end) in enumerate(offsets):
            if start <= answer_start < end:
                start_position = j
            if start < answer_end <= end:
                end_position = j
                break

        start_positions.append(start_position)
        end_positions.append(end_position)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

tokenized_train = train_dataset.map(preprocess, batched=True, remove_columns=train_dataset.column_names)
tokenized_test = test_dataset.map(preprocess, batched=True, remove_columns=test_dataset.column_names)

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    # learning_rate=3e-5,
    learning_rate=15e-6,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    warmup_steps=500,
    logging_dir='./logs',
    logging_steps=10,
    fp16=True
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
    tokenizer=tokenizer,
    data_collator=default_data_collator,
)

# Trains the model
trainer.train()

# Save the model and tokenizer
model.save_pretrained("model")
tokenizer.save_pretrained("tokenizer")
# Out:
# Map:   0%|          | 0/33399 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3712 [00:00<?, ? examples/s]
# /home/dbhatka/.local/lib/python3.11/site-packages/transformers/training_args.py:1559: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /local_scratch/slurm.979168/ipykernel_1416537/3165334640.py:68: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='6267' max='6267' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6267/6267 24:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.759000</td>
#       <td>3.167040</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.402700</td>
#       <td>3.067386</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.238900</td>
#       <td>3.138374</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/dbhatka/.local/lib/python3.11/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ('tokenizer/tokenizer_config.json',
#  'tokenizer/special_tokens_map.json',
#  'tokenizer/vocab.txt',
#  'tokenizer/added_tokens.json',
#  'tokenizer/tokenizer.json')

# %% [markdown]
# ## Load model

# %%
from transformers import BertTokenizerFast, BertForQuestionAnswering, Trainer
import torch
from datasets import Dataset, load_dataset
import json

# Load the trained model and tokenizer
model_path = "model"
tokenizer_path = "tokenizer"

model = BertForQuestionAnswering.from_pretrained(model_path)
tokenizer = BertTokenizerFast.from_pretrained(tokenizer_path)

# %% [markdown]
# ### Prepares the evaluation data

# %%
with open("spoken_test-v1.1.json", "r") as f:
    squad_data = json.load(f)


contexts = []
questions = []
answers = []

for article in squad_data["data"]:
    for paragraph in article["paragraphs"]:
        context = paragraph["context"]
        for qa in paragraph["qas"]:
            question = qa["question"]
            answer = qa["answers"][0]
            contexts.append(context)
            questions.append(question)
            answers.append(answer)

# Converts to Hugging Face Dataset format
dataset_dict = {
    "context": contexts,
    "question": questions,
    "answers": answers
}
dataset = Dataset.from_dict(dataset_dict)

# %%
def preprocess_validation(examples):
    questions = examples["question"]
    contexts = examples["context"]
    inputs = tokenizer(
        questions,
        contexts,
        max_length=512,
        truncation="only_second",
        stride=128,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length"
    )
    

    inputs["offset_mapping"] = [
        offset if i < len(inputs["overflow_to_sample_mapping"]) else None
        for i, offset in enumerate(inputs["offset_mapping"])
    ]
    
    return inputs

# Applies the modified preprocessing
tokenized_eval = dataset.map(preprocess_validation, batched=True, remove_columns=dataset.column_names)
# Out:
# Map:   0%|          | 0/5351 [00:00<?, ? examples/s]

# %% [markdown]
# ### Predictions

# %%
trainer = Trainer(model=model)

predictions = trainer.predict(tokenized_eval)
start_logits, end_logits = predictions.predictions

def get_predicted_answers(context, offset_mapping, start_logits, end_logits):
    start_index = torch.argmax(torch.tensor(start_logits)).item()
    end_index = torch.argmax(torch.tensor(end_logits)).item()
    
    if start_index < len(offset_mapping) and end_index < len(offset_mapping):
        start_char = offset_mapping[start_index][0]
        end_char = offset_mapping[end_index][1]
        return context[start_char:end_char]
    return ""


for i, example in enumerate(dataset):
    question = example["question"]
    context = example["context"]
    actual_answer = example["answers"]["text"][0]
    
    offset_mapping = tokenized_eval[i]["offset_mapping"]
    
    # gets predicted answer
    predicted_answer = get_predicted_answers(
        context, offset_mapping, start_logits[i], end_logits[i]
    )
    
    print(f"Question: {question}")
    print(f"Predicted Answer: {predicted_answer}")
    print(f"Actual Answer: {actual_answer}")
    print("\n")
# Out:
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Question: Which NFL team represented the AFC at Super Bowl 50?
# Predicted Answer:
# Actual Answer: d
#
#
# Question: Which NFL team represented the NFC at Super Bowl 50?
# Predicted Answer: carolina panthers
# Actual Answer: c
#
#
# Question: Where did Super Bowl 50 take place?
# Predicted Answer:
# Actual Answer: s
#
#
# Question: Which NFL team won Super Bowl 50?
# Predicted Answer:
# Actual Answer: d
#
#
# Question: What color was used to emphasize the 50th anniversary of the Super Bowl?
# Predicted Answer: roman
# Actual Answer: g
#
#
# Question: What was the theme of Super Bowl 50?
# Predicted Answer: champion of the national football league nfl
# Actual Answer: g
#
#
# Question: What is the AFC short for?
# Predicted Answer:
# Actual Answer: a
#
#
# Question: What was the theme of Super Bowl 50?
# Predicted Answer: champion of the national football league nfl
# Actual Answer: g
#
#
# Question: What does AFC stand for?
# Predicted Answer:
# Actual Answer: a
#
#
# Question: Who won Super Bowl 50?
# Predicted Answer:
# Actual Answer: d
#
#
# Question: What venue did Super Bowl 50 take place in?
# Predicted Answer: levis stadium
# Actual Answer: l
#
#
# Question: What city did Super Bowl 50 take place in?
# Predicted Answer: san francisco
# Actual Answer: s
#
#
# Question: If Roman numerals were used, what would Super Bowl 50 have been called?
# Predicted Answer: super bowl
# Actual Answer: s
#
#
# Question: What city did Super Bowl 50 take place in?
# Predicted Answer: san francisco
# Actual Answer: s
#
#
# Question: What stadium did Super Bowl 50 take place in?
# Predicted Answer: levis stadium
# Actual Answer: l
#
#
# Question: What team was the AFC champion?
# Predicted Answer:
# Actual Answer: d
#
#
# Question: What team was the NFC champion?
# Predicted Answer: carolina panthers
# Actual Answer: c
#
#
# Question: Who won Super Bowl 50?
# Predicted Answer:
# Actual Answer: d
#
#
# Question: Which team won Super Bowl 50.
# Predicted Answer:
# Actual Answer: d
#
#
# Question: Where was Super Bowl 50 held?
# Predicted Answer:
# Actual Answer: s
#
#
# Question: The name of the NFL championship game is?
# Predicted Answer: super bowl fifty was an american football game to determine the champion of the national football league nfl
# Actual Answer: s
#
#
# Question: What 2015 NFL team one the AFC playoff?
# Predicted Answer:
# Actual Answer: d
#
#
# Question: How many appearances have the Denver Broncos made in the Super Bowl?
# Predicted Answer: twelve to four
# Actual Answer: e
#
#
# Question: What team did the Panthers defeat?
# Predicted Answer: arizona cardinals
# Actual Answer: a
#
#
# Question: Who did the Broncos prevent from going to the Super Bowl?
# Predicted Answer: new england patriots
# Actual Answer: n
#
#
# Question: Who did the Panthers beat in the NFC Championship Game?
# Predicted Answer: arizona cardinals
# Actual Answer: a
#
#
# Question: Who lost to the Broncos in the AFC Championship?
# Predicted Answer: arizona cardinals forty nine to fifteen in the n f c championship game in advance to their second super bowl appearance since the franchise was founded in nineteen ninety five. the broncos finished the regular season with a twelve to four record and denied the new england patriots
# Actual Answer: n
#
#
# Question: Who were the defending Super Bowl champions?
# Predicted Answer: new england patriots
# Actual Answer: n
#
#
# Question: How many teams have been in the Super Bowl eight times?
# Predicted Answer: the panthers finished the regular season with the fifteen to one record and quarterback can newton was named the n f l most valuable player and the p. they defeated the arizona cardinals forty nine to fifteen in the n f c championship game in advance to their second super bowl appearance since the franchise was founded in nineteen ninety five. the broncos finished the regular season with a twelve to four
# Actual Answer: f
#
#
# Question: How many teams have played in the Super Bowl eight times?
# Predicted Answer: the panthers finished the regular season with the fifteen to one record and quarterback can newton was named the n f l most valuable player and the p. they defeated the arizona cardinals forty nine to fifteen in the n f c championship game in advance to their second super bowl appearance since the franchise was founded in nineteen ninety five. the broncos finished the regular season with a twelve to four
# Actual Answer: f
#
#
# Question: Which team did not get a chance to defend their Super Bowl XLIX win in Super Bowl 50?
# Predicted Answer: new england patriots
# Actual Answer: n
#
#
# Question: Who did Carolina beat in the NFC championship game?
# Predicted Answer: arizona cardinals
# Actual Answer: a
#
#
# Question: How many times have the Panthers been in the Super Bowl?
# Predicted Answer: fifteen
# Actual Answer: s
#
#
# Question: Who did Denver beat in the AFC championship?
# Predicted Answer: arizona cardinals
# Actual Answer: n
#
#
# Question: Who did Denver beat in the 2015 AFC Championship game?
# Predicted Answer: arizona cardinals
# Actual Answer: n
#
#
# Question: Who did the Carolina Panthers beat in the 2015 NFC Championship game?
# Predicted Answer: arizona cardinals
# Actual Answer: a
#
#
# Question: Who did the Panthers beat to become the NFC champs?
# Predicted Answer: arizona cardinals
# Actual Answer: a
#
#
# Question: Who was the Super Bowl 50 MVP?
# Predicted Answer: john miller
# Actual Answer: m
#
#
# Question: How many fumbles did Von Miller force in Super Bowl 50?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: Which team held the scoring lead throughout the entire game?
# Predicted Answer:
# Actual Answer: b
#
#
# Question: Which Denver linebacker was named Super Bowl MVP?
# Predicted Answer: john miller
# Actual Answer: m
#
#
# Question: How many solo tackles did Von Miller make at Super Bowl 50?
# Predicted Answer: five
# Actual Answer: f
#
#
# Question: Who was limited by Denver's defense?
# Predicted Answer: newton
# Actual Answer: n
#
#
# Question: How many times was Cam Newton sacked?
# Predicted Answer: seven
# Actual Answer: s
#
#
# Question: Who won the Super Bowl MVP?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: How many turnovers did Cam Newton have?
# Predicted Answer: three
# Actual Answer: t
#
#
# Question: How many fumbles did Von Miller force?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: Who was given the esteemed status of MVP for Super Bowl 50?
# Predicted Answer:
# Actual Answer: m
#
#
# Question: What position does Von Miller play for the Denver Broncos?
# Predicted Answer: linebacker
# Actual Answer: l
#
#
# Question: What was the number of solo tackles that Von Miller had in Super Bowl 50?
# Predicted Answer: five
# Actual Answer: f
#
#
# Question: How many forced fumbles did Von Miller have during the Super Bowl 50 game?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: How many tackles did Von Miller get during the game?
# Predicted Answer: five
# Actual Answer: f
#
#
# Question: How many times was Cam Newton sacked in Super Bowl 50?
# Predicted Answer: seven
# Actual Answer: s
#
#
# Question: How many times did the Denver defense force Newton into turnovers?
# Predicted Answer: seven
# Actual Answer: t
#
#
# Question: Which Newton turnover resulted in seven points for Denver?
# Predicted Answer:
# Actual Answer: f
#
#
# Question: What position does Von Miller play?
# Predicted Answer: linebacker
# Actual Answer: l
#
#
# Question: How many times was the Panthers' quarterback sacked?
# Predicted Answer: seven
# Actual Answer: s
#
#
# Question: How many times did the Broncos cause turnovers in the game?
# Predicted Answer: seven times and forced him into three
# Actual Answer: t
#
#
# Question: How many tackles did Von Miller accomlish by himself in the game?
# Predicted Answer: five
# Actual Answer: f
#
#
# Question: What halftime performer previously headlined Super Bowl XLVIII?
# Predicted Answer: bruno mars
# Actual Answer: b
#
#
# Question: Who was the male singer who performed as a special guest during Super Bowl 50?
# Predicted Answer: bruno mars
# Actual Answer: b
#
#
# Question: What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# Predicted Answer: third
# Actual Answer: t
#
#
# Question: What performer lead the Super Bowl XLVIII halftime show?
# Predicted Answer: bruno mars
# Actual Answer: b
#
#
# Question: In early 2012, Goodell said that Super Bowl 50 would be what?
# Predicted Answer:
# Actual Answer: s
#
#
# Question: What one word did the NFL commissioner use to describe what Super Bowl 50 was intended to be?
# Predicted Answer: spectacular
# Actual Answer: s
#
#
# Question: Which California venue was one of three considered for Super Bowl 50?
# Predicted Answer: new orleans mercedes benz superdome
# Actual Answer: s
#
#
# Question: What site is located in the San Francisco Bay Area?
# Predicted Answer: new orleans mercedes benz superdome me yeah nice on lifes stadium in the san francisco bay areas levis stadium
# Actual Answer: l
#
#
# Question: What is the name of San Francisco's stadium when looked at as a possibility for Super Bowl 50?
# Predicted Answer: levis stadium
# Actual Answer: l
#
#
# Question: How many sites did the NFL narrow down Super Bowl 50's location to?
# Predicted Answer: three
# Actual Answer: t
#
#
# Question: One of the sites, Merceds-Benz Superdome, is located where?
# Predicted Answer: new orleans
# Actual Answer: n
#
#
# Question: What was the third city that was considered?
# Predicted Answer: new orleans
# Actual Answer: s
#
#
# Question: What is the name of the stadium in San Francisco Bay Area?
# Predicted Answer: levis stadium
# Actual Answer: l
#
#
# Question: What is the name of the stadium where Super Bowl 50 was played?
# Predicted Answer: new orleans mercedes benz superdome me yeah nice on lifes stadium in the san francisco bay areas levis stadium
# Actual Answer: l
#
#
# Question: In what venue did Super Bowl XIX take place?
# Predicted Answer: stanford stadium
# Actual Answer: s
#
#
# Question: How many times has a Super Bowl taken place at Miami's Sun Life Stadium?
# Predicted Answer: ten times
# Actual Answer: t
#
#
# Question: In 2012, how many stadiums were named as finalists for hosting Super Bowl 50 before the final stadium was chosen?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: What was the entity that stepped in and caused Miami's Sun Life Stadium to no longer be in the running to host Super Bowl 50?
# Predicted Answer: the florida legislature
# Actual Answer: f
#
#
# Question: What other city has hosted the Super Bowl ten times?
# Predicted Answer: new orleans
# Actual Answer: n
#
#
# Question: What city is tied with Miami for hosting the Super Bowl?
# Predicted Answer: new orleans
# Actual Answer: n
#
#
# Question: Who decided not to approve paying for renovations at Sun Life Stadium that the league wanted for them to do to host Super Bowl 50?
# Predicted Answer: the florida legislature
# Actual Answer: f
#
#
# Question: Who voted on the venue for Super Bowl 50?
# Predicted Answer: on may twenty first twenty thirteen nfl owners that their spring meetings in boston voted and awarded the game to levis stadium
# Actual Answer: n
#
#
# Question: What California city last hosted the Super Bowl?
# Predicted Answer: san francisco bay area since super bowl x x in nineteen eighty five and the first in california since super bowl x x x b i took place in san diego
# Actual Answer: s
#
#
# Question: Where did the spring meetings of the NFL owners take place?
# Predicted Answer: boston
# Actual Answer: b
#
#
# Question: In what city did the last Super Bowl in California occur?
# Predicted Answer: san francisco bay area since super bowl x x in nineteen eighty five and the first in california since super bowl x x x b i took place in san diego
# Actual Answer: s
#
#
# Question: Where was the meeting held when the NFL owners voted on the location for Super Bowl 50?
# Predicted Answer: boston
# Actual Answer: b
#
#
# Question: Who coached each Super Bowl 50 participant in their most recent Super Bowl appearance prior to Super Bowl 50?
# Predicted Answer: john fox
# Actual Answer: j
#
#
# Question: How many NFL teams have finished the regular season with one loss?
# Predicted Answer: ten
# Actual Answer: t
#
#
# Question: How many NFL teams have gone 15-1 in one season?
# Predicted Answer: six
# Actual Answer: s
#
#
# Question: Which team in Super Bowl 50 had a 15-1 record?
# Predicted Answer: the carolina panthers
# Actual Answer: c
#
#
# Question: Who was the head coach of the Broncos in Super Bowl XLVIII?
# Predicted Answer: john fox
# Actual Answer: j
#
#
# Question: How many NFL teams have had only one loss by the end of a regular season?
# Predicted Answer: ten
# Actual Answer: t
#
#
# Question: How many teams can boast a 15–1 regular season record?
# Predicted Answer: six
# Actual Answer: s
#
#
# Question: What seed was the Carolina Panthers?
# Predicted Answer: for the third straight season the number one seats from both conferences met in the super bowl. the carolina panthers became one of only ten teams to have completed your regular season with only one loss and one of only six teams to have acquired a fifteen to one record while the denver broncos
# Actual Answer: n
#
#
# Question: What seed was the Denver Broncos?
# Predicted Answer: carolina panthers
# Actual Answer: n
#
#
# Question: How many teams have had a 15-1 record for the regular season?
# Predicted Answer: six
# Actual Answer: s
#
#
# Question: How many games did the Panthers lose in the regular season before Super Bowl 50?
# Predicted Answer: ten
# Actual Answer: o
#
#
# Question: How many teams up to Super Bowl 50 have been to the championship game eight times?
# Predicted Answer:
# Actual Answer: f
#
#
# Question: Before Super Bowl 50, what was the coach's name that coached both teams for their last Super Bowl appearances?
# Predicted Answer: john fox
# Actual Answer: j
#
#
# Question: Whic Carolina Panthers running back was waived?
# Predicted Answer: despite waving long time running ba
# Actual Answer: w
#
#
# Question: Which Carolina Panthers wide receiver suffered a torn ACL before the season began?
# Predicted Answer: kelvin benjamin
# Actual Answer: k
#
#
# Question: Who had the best record in the NFC?
# Predicted Answer: carolina panthers
# Actual Answer: c
#
#
# Question: How many Panthers went to the Pro Bowl?
# Predicted Answer: ten
# Actual Answer: t
#
#
# Question: How many Panthers were designated All-Pro?
# Predicted Answer: seventeen
# Actual Answer: e
#
#
# Question: What Panther tore his ACL in the preseason?
# Predicted Answer: kelvin benjamin
# Actual Answer: k
#
#
# Question: Which player did the Panthers lose to an ACL injury in a preseason game?
# Predicted Answer: kelvin benjamin
# Actual Answer: k
#
#
# Question: Which running back did the Panthers waive?
# Predicted Answer:
# Actual Answer: w
#
#
# Question: How many Panthers players were selected to the Pro Bowl?
# Predicted Answer: ten
# Actual Answer: t
#
#
# Question: Which team had the best regular season in their history?
# Predicted Answer: carolina panthers
# Actual Answer: c
#
#
# Question: What team had the best start ever in the NFL?
# Predicted Answer: carolina panthers
# Actual Answer: c
#
#
# Question: How many Panthers players were chosen for the 2015 season's Pro Bowl?
# Predicted Answer: ten
# Actual Answer: t
#
#
# Question: How many Pro Bowlers were on the Panthers offense?
# Predicted Answer: six
# Actual Answer: s
#
#
# Question: Who started at tight end for the Panthers?
# Predicted Answer: ted guinn
# Actual Answer: g
#
#
# Question: What position does Jerricho Cotchery play?
# Predicted Answer:
# Actual Answer: r
#
#
# Question: Which Panthers RB scored 6 TDs in the 13 games leading up to Super Bowl 50?
# Predicted Answer: the panthers offense which led the n f l in sc
# Actual Answer: j
#
#
# Question: How many Offensive players from the Panthers were selected to play in the Pro Bowl?
# Predicted Answer: six
# Actual Answer: s
#
#
# Question: How many touchdowns did Jonathan Stewart have in 13 games?
# Predicted Answer: six
# Actual Answer: s
#
#
# Question: How many balls did Josh Norman intercept?
# Predicted Answer:
# Actual Answer: f
#
#
# Question: Who registered the most sacks on the team this season?
# Predicted Answer: mario addison
# Actual Answer: s
#
#
# Question: Who led the Panthers in sacks?
# Predicted Answer: mario addison
# Actual Answer: s
#
#
# Question: How many Panthers defense players were selected for the Pro Bowl?
# Predicted Answer:
# Actual Answer: f
#
#
# Question: How many forced fumbles did Thomas Davis have?
# Predicted Answer:
# Actual Answer: f
#
#
# Question: Which player had the most interceptions for the season?
# Predicted Answer: josh norman
# Actual Answer: k
#
#
# Question: Who was the Panthers' tackle leader for 2015?
# Predicted Answer: jared alan
# Actual Answer: s
#
#
# Question: Who is the head coach of the Broncos?
# Predicted Answer:
# Actual Answer: g
#
#
# Question: Who did Peyton Manning play for as a rookie?
# Predicted Answer: indianapolis colts
# Actual Answer: i
#
#
# Question: Who did the Broncos play in the last week of the regular season?
# Predicted Answer: san diego chargers
# Actual Answer: s
#
#
# Question: Who is Denver's defensive coordinator?
# Predicted Answer: gary kubiak
# Actual Answer: w
#
#
# Question: How many years was John Fox the head coach of the Denver Broncos?
# Predicted Answer: four
# Actual Answer: f
#
#
# Question: What is the name of the Bronco's head coach, who was hired after John Fox?
# Predicted Answer: gary kubiak
# Actual Answer: g
#
#
# Question: What was the first team Peyton Manning began playing for?
# Predicted Answer:
# Actual Answer: i
#
#
# Question: When John Fox left as head coach for the Broncos, who replaced him?
# Predicted Answer: gary kubiak
# Actual Answer: g
#
#
# Question: Who was the quarterback for the Broncos 2015 season?
# Predicted Answer: gary kubiak
# Actual Answer: p
#
#
# Question: How many games did the Broncos lose during their regular 2015 season?
# Predicted Answer: thirteen to seven
# Actual Answer: f
#
#
# Question: What coach left the Broncos after the season prior to Super Bowl 50?
# Predicted Answer: gary kubiak
# Actual Answer: f
#
#
# Question: According to game stats, which Super Bowl 50 quarterback had his worst year since his first season as a player in the NFL?
# Predicted Answer: peyton manning
# Actual Answer: p
#
#
# Question: Who was the Denver head coach for Super Bowl 50?
# Predicted Answer:
# Actual Answer: g
#
#
# Question: What foot was injured on Manning that sidelined him in week 10?
# Predicted Answer: left foot
# Actual Answer: l
#
#
# Question: Who was the defensive coordinator for the Broncos in 2015?
# Predicted Answer: gary kubiak
# Actual Answer: w
#
#
# Question: Who registered the most receptions on the Broncos?
# Predicted Answer: emmanuel sanders
# Actual Answer: t
#
#
# Question: Who had the most rushing yards on the Broncos?
# Predicted Answer: emmanuel sanders
# Actual Answer: a
#
#
# Question: What was the number of 17 interceptions that Peyton Manning had by end of the year?
# Predicted Answer: seventeen
# Actual Answer: n
#
#
# Question: Who had the most receptions out of all players for the year?
# Predicted Answer: emmanuel sanders
# Actual Answer: t
#
#
# Question: What position does Demaryius Thomas play?
# Predicted Answer: manning finished the year with a career los sixty seven nine passer raiding throwing for two two hundred forty nine yards and nine touch downs with seventeen interceptions. in contrast os wyler through for wine nine hundred sixty seven yards ten touchdowns in six interceptions for reading of the eighty sixth floor. that are in receiver
# Actual Answer: r
#
#
# Question: Who led the Broncos with 105 receptions?
# Predicted Answer: thomas
# Actual Answer: t
#
#
# Question: How many touchdowns did Ronnie Hillman make?
# Predicted Answer: seventeen
# Actual Answer: f
#
#
# Question: What Denver player caught the ball 76 times in the 2015 season?
# Predicted Answer: emmanuel sanders
# Actual Answer: e
#
#
# Question: Who was the Broncos' leading rusher for the 2015 season?
# Predicted Answer: emmanuel sanders
# Actual Answer: a
#
#
# Question: Who was first on the team in total tackles?
# Predicted Answer: brendan marshall
# Actual Answer: m
#
#
# Question: How many picks did Aqib Talib have?
# Predicted Answer: five and a half sacks
# Actual Answer: t
#
#
# Question: What position does DeMarcus currently play?
# Predicted Answer: linebacker
# Actual Answer: l
#
#
# Question: What position does Brandon Marshall currently play?
# Predicted Answer: linebacker
# Actual Answer: l
#
#
# Question: Which linebacker had the most sacks on the team?
# Predicted Answer: john miller
# Actual Answer: m
#
#
# Question: Which linebacker led the Broncos in tackles?
# Predicted Answer: brendan marshall
# Actual Answer: m
#
#
# Question: How many interceptions did Aqib Talib have for the regular season?
# Predicted Answer: five and a half sacks
# Actual Answer: t
#
#
# Question: Who forced four fumbles for the Broncos in the 2015 season?
# Predicted Answer: john miller
# Actual Answer: m
#
#
# Question: What Denver player had 109 tackels for the 2015 season?
# Predicted Answer: derek wall
# Actual Answer: m
#
#
# Question: Who lost to the Panthers in the divisional round of the playoffs?
# Predicted Answer: the panthers speak the seattle seahawks
# Actual Answer: s
#
#
# Question: Who did the Panthers face in the NFC Championship Game?
# Predicted Answer: arizona cardinals
# Actual Answer: a
#
#
# Question: How many times did Arizona turn the ball over in the NFC Championship?
# Predicted Answer: four
# Actual Answer: s
#
#
# Question: What was the team the Carolina Panthers played immediately prior to the NFC Championship game?
# Predicted Answer: arizona cardinals
# Actual Answer: s
#
#
# Question: Who did Carolina beat in the divisional round?
# Predicted Answer: seattle seahawks
# Actual Answer: s
#
#
# Question: Who did the Panthers play to advance to the Super Bowl?
# Predicted Answer: seattle seahawks in the divisional around running up a thirty one to zero halftime lead and then holding off the furious second half comeback attempt to win there he wanted twenty four avenging their elimination from a year earlier. the panthers then blew out the arizona cardinals
# Actual Answer: a
#
#
# Question: How many turnovers did the Panthers force during the NFC Championship game?
# Predicted Answer: seven
# Actual Answer: s
#
#
# Question: Who did the Panthers beat in the divisional round?
# Predicted Answer: seattle seahawks
# Actual Answer: s
#
#
# Question: Who did the Panthers play in their division championship game?
# Predicted Answer: arizona cardinals
# Actual Answer: a
#
#
# Question: Who lost to the Broncos in the divisional round?
# Predicted Answer: the broncos defeated the pittsburgh steelers
# Actual Answer: p
#
#
# Question: Who won Super Bowl XLIX?
# Predicted Answer: new england patriots
# Actual Answer: n
#
#
# Question: What team was the divisional round winner between the Broncos and Steelers?
# Predicted Answer: new england patriots
# Actual Answer: b
#
#
# Question: Who won Super Bowl XLIX?
# Predicted Answer: new england patriots
# Actual Answer: n
#
#
# Question: During the Bronco's playoff games, who did not throw at all?
# Predicted Answer: manning
# Actual Answer: m
#
#
# Question: Who did the Broncos beat in the divisional game?
# Predicted Answer:
# Actual Answer: p
#
#
# Question: Who did the Broncos defeat in the AFC Championship game?
# Predicted Answer: new england patriots
# Actual Answer: n
#
#
# Question: Who did the Broncos beat to win their division in 2015?
# Predicted Answer:
# Actual Answer: p
#
#
# Question: Who did the Broncos beat tp become the AFC champions?
# Predicted Answer: new england patriots
# Actual Answer: n
#
#
# Question: What Carolina player was injured in the NFC Championship Game?
# Predicted Answer: thomas davis
# Actual Answer: t
#
#
# Question: What injury did Thomas Davis suffer in the NFC Championship?
# Predicted Answer: a broken arm
# Actual Answer: a
#
#
# Question: How many times had Thomas Davis torn his ACL in his career?
# Predicted Answer: three
# Actual Answer: t
#
#
# Question: What body part did Thomas Davis break during the NFC Championship Game?
# Predicted Answer: carolinas suffered a major setback when thomas davis an eleven year veteran who had already overcome three a c l tears in his career went down with a broken arm
# Actual Answer: a
#
#
# Question: What game did Thomas Davis say he would play in, despite breaking a bone earlier on?
# Predicted Answer: super bowl
# Actual Answer: s
#
#
# Question: How many ACL injuries has Thomas Davis had during his career?
# Predicted Answer: three
# Actual Answer: t
#
#
# Question: What injury did Thomas Davis suffer during the playoff games?
# Predicted Answer: a broken arm
# Actual Answer: b
#
#
# Question: Who suffered a broken arm in the NFC Championship Game?
# Predicted Answer: thomas davis
# Actual Answer: t
#
#
# Question: Who previously held the record for being the oldest quarterback to play in a Super Bowl?
# Predicted Answer: john elway
# Actual Answer: j
#
#
# Question: Who did John Elway play for in Super Bowl XXXIII?
# Predicted Answer: broncos
# Actual Answer: b
#
#
# Question: What team was the winner of Super Bowl XXXIII?
# Predicted Answer: peyton manning became the first quarterback ever to lead to a different teams to multiple super bowls. he is also the oldest quarterback ever to play in the super bowl at age thirty nine. the past record was held by john elway who led the broncos
# Actual Answer: b
#
#
# Question: Who is the General Manager for the Broncos?
# Predicted Answer: john elway
# Actual Answer: j
#
#
# Question: Who has the record of being the oldest quarter back in any Super Bowl game?
# Predicted Answer: john elway
# Actual Answer: p
#
#
# Question: Who is the oldest quarterback to play in a Super Bowl?
# Predicted Answer: peyton manning be
# Actual Answer: p
#
#
# Question: Prior to Manning, who was the oldest quarterback to play in a Super Bowl?
# Predicted Answer: john elway
# Actual Answer: j
#
#
# Question: Who was the first quarterback to take two teams to more than one Super Bowl?
# Predicted Answer: peyton manning be
# Actual Answer: p
#
#
# Question: What is the name of the quarterback who was 38 in Super Bowl XXXIII?
# Predicted Answer: peyton manning became the first quarterback ever to lead to a different teams to multiple super bowls. he is also the oldest quarterback ever to play in the super bowl at age thirty nine. the past record was held by john elway
# Actual Answer: j
#
#
# Question: Who was the #2 pick in the 2011 NFL Draft?
# Predicted Answer: manning
# Actual Answer: m
#
#
# Question: Who was considered to be the first choice in the NFL draft of 1998?
# Predicted Answer: manning
# Actual Answer: m
#
#
# Question: In 2011, who was the first player to be chosen in the NFL draft?
# Predicted Answer: manning
# Actual Answer: n
#
#
# Question: What position did Newton play during Super Bowl 50?
# Predicted Answer: quarterback
# Actual Answer: q
#
#
# Question: Who was the number two draft pick for 2011?
# Predicted Answer: manning
# Actual Answer: m
#
#
# Question: What team did Rivera play for in Super Bowl XX?
# Predicted Answer: chicago bears
# Actual Answer: c
#
#
# Question: What position did Rivera play in Super Bowl XX?
# Predicted Answer: linebacker
# Actual Answer: l
#
#
# Question: Who was replaced by Kubiak in Super Bowl XXIV?
# Predicted Answer: elway
# Actual Answer: e
#
#
# Question: What team did Kubiak play for in Super Bowl XXI?
# Predicted Answer: with rivera having been a linebacker with the chicago bears
# Actual Answer: b
#
#
# Question: What position did Rivera play in Super Bowl XX?
# Predicted Answer: linebacker
# Actual Answer: l
#
#
# Question: Who did Kubiak take the place of after Super Bowl XXIV?
# Predicted Answer: elway
# Actual Answer: e
#
#
# Question: Who was the Panthers head coach for the 2015 season?
# Predicted Answer:
# Actual Answer: r
#
#
# Question: Who slipped on the Levi's Stadium turf in week 6 of the 2015 NFL season?
# Predicted Answer: justin tucker
# Actual Answer: j
#
#
# Question: What team did Justin Tucker play for?
# Predicted Answer: baltimore ravens
# Actual Answer: b
#
#
# Question: What position did Justin Tucker play?
# Predicted Answer: baltimore ravens
# Actual Answer: k
#
#
# Question: Which player did the turf collapse under during a game in the Levi's Stadium?
# Predicted Answer: baltimore ravens kicker justin tucker
# Actual Answer: j
#
#
# Question: What position does Tucker play for with the Ravens?
# Predicted Answer:
# Actual Answer: k
#
#
# Question: Which kicker had a portion of the turf collapse, causing him to miss a field goal?
# Predicted Answer: justin tucker
# Actual Answer: j
#
#
# Question: What did a lot of players need to change during Super Bowl 50 because of the condition of the field?
# Predicted Answer: cleats
# Actual Answer: t
#
#
# Question: What player did the field problem at Levi's stadium affect for a field goal in week six of the regular season?
# Predicted Answer: justin tucker
# Actual Answer: j
#
#
# Question: What field type is usually chosen for Super Bowl games?
# Predicted Answer: natural grass
# Actual Answer: n
#
#
# Question: Who was designated as the home team in the Super Bowl?
# Predicted Answer: pittsburgh steelers
# Actual Answer: b
#
#
# Question: What team lost Super Bowl XXXIII?
# Predicted Answer: broncos
# Actual Answer: a
#
#
# Question: What color pants did the Broncos wear in Super Bowl 50?
# Predicted Answer: white jerseys with matching white
# Actual Answer: w
#
#
# Question: What team did the Denver Broncos play in  Super Bowl XXXIII?
# Predicted Answer: atlanta falcons
# Actual Answer: a
#
#
# Question: What color were the Bronco's uniforms in Super Bowl 50?
# Predicted Answer: white jerseys with matching white
# Actual Answer: w
#
#
# Question: What jersey did the Broncos wear for Super Bowl 50?
# Predicted Answer: white
# Actual Answer: m
#
#
# Question: Who is the only other AFC Champion team to wear road jerseys in a Super Bowl?
# Predicted Answer: pittsburgh steelers
# Actual Answer: p
#
#
# Question: What was the color of the jerseys in Super Bowl XXXII when Elway was quarterback?
# Predicted Answer: white
# Actual Answer: b
#
#
# Question: What color jersey has Denver 0-4?
# Predicted Answer: white
# Actual Answer: o
#
#
# Question: Since Denver chose white, what colors did Carolina wear in Super Bowl 50?
# Predicted Answer: white pants
# Actual Answer: b
#
#
# Question: At what university's facility did the Panthers practice?
# Predicted Answer: stanford university
# Actual Answer: s
#
#
# Question: At what university's facility did the Broncos practice?
# Predicted Answer: stanford university
# Actual Answer: s
#
#
# Question: In what city's Marriott did the Panthers stay?
# Predicted Answer:
# Actual Answer: s
#
#
# Question: In what city's Marriott did the Broncos stay?
# Predicted Answer:
# Actual Answer: s
#
#
# Question: Where did the Panthers practice at for Super Bowl 50?
# Predicted Answer: san jose state practice facility
# Actual Answer: s
#
#
# Question: Where did the Broncos practice at for Super Bowl 50?
# Predicted Answer: stanford university
# Actual Answer: s
#
#
# Question: Where did the Panthers practice for the Super Bowl?
# Predicted Answer: san jose state practice facility
# Actual Answer: s
#
#
# Question: Where did the Broncos practice for the Super Bowl?
# Predicted Answer: stanford university
# Actual Answer: s
#
#
# Question: Where was the practice place the Panthers used for the Super Bowl?
# Predicted Answer:
# Actual Answer: s
#
#
# Question: Where did the Broncos practice for the Super Bowl?
# Predicted Answer: stanford university
# Actual Answer: s
#
#
# Question: What was the first Super Bowl branded with Roman numerals?
# Predicted Answer:
# Actual Answer: s
#
#
# Question: What was the first Super Bowl to use the standardized logo template?
# Predicted Answer:
# Actual Answer: v
#
#
# Question: Who is the trophy featured on the logo named for?
# Predicted Answer: vince lombardi
# Actual Answer: v
#
#
# Question: Which Super Bowl, after the 50th one, will begin have Roman numerals in the title again?
# Predicted Answer: super bowl fifty
# Actual Answer: l
#
#
# Question: If Roman numerals were used in the naming of the 50th Super Bowl, which one would have been used?
# Predicted Answer: on june fourth twenty fourteen the nfl announced that the practice of branding super bowl games with roman numerals practice established that super bowl v would be temporarily suspended and that the game would be named using arabic numerals is super bowl fifty
# Actual Answer: l
#
#
# Question: Rather than Roman numerals, what did the NFL decide to use?
# Predicted Answer: arabic numerals
# Actual Answer: a
#
#
# Question: What is the Roman numeral for 50?
# Predicted Answer: arabic numerals is super bowl fifty
# Actual Answer: l
#
#
# Question: What type of numeral did the latest Super Bowl use to designate the game number?
# Predicted Answer: roman
# Actual Answer: a
#
#
# Question: What is the Roman numeral going to be for Super Bowl 51?
# Predicted Answer: on june fourth twenty fourteen the nfl announced that the practice of branding super bowl games with roman numerals practice established that super bowl v would be temporarily suspended and that the game would be named using arabic numerals
# Actual Answer: l
#
#
# Question: What color was featured in promotions related to Super Bowl 50?
# Predicted Answer: gold
# Actual Answer: g
#
#
# Question: What color was used to create the 50-yard line in Levi's Stadium for the season leading up to the Super Bowl 50 game?
# Predicted Answer: gold
# Actual Answer: g
#
#
# Question: What color were the footballs handed out to a variety of high schools, leading up to Super Bowl 50?
# Predicted Answer: gold
# Actual Answer: g
#
#
# Question: What was given to high schools where former students went on to play or coach in a Super Bowl?
# Predicted Answer: gold footballs
# Actual Answer: g
#
#
# Question: Since this was the 50th one, what was the theme color for the Super Bowl?
# Predicted Answer: gold
# Actual Answer: g
#
#
# Question: In what city is the Moscone Center located?
# Predicted Answer: san francisco
# Actual Answer: s
#
#
# Question: What was the name of the event at the The Embarcadero that was held prior to Super Bowl 50 to help show off some of the things that San Francisco has to offer?
# Predicted Answer: super bowl city opened on january thirtieth that justin hermann plaza
# Actual Answer: s
#
#
# Question: What opened on January 30th at the Justin Herman plaza?
# Predicted Answer: super bowl city
# Actual Answer: s
#
#
# Question: What football associated thing started at Justin Herman Plaza in January?
# Predicted Answer: super bowl city
# Actual Answer: s
#
#
# Question: What did the Moscone Center host?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: At what university is Bellomy Field located?
# Predicted Answer: santa clara university
# Actual Answer: s
#
#
# Question: How long will the event at Santa Clara Convention Center last?
# Predicted Answer: week
# Actual Answer: a
#
#
# Question: What type of rally was held?
# Predicted Answer: pep rally
# Actual Answer: p
#
#
# Question: Which government entity helped to pay for the festivities, beyond businesses and individuals?
# Predicted Answer: city council
# Actual Answer: c
#
#
# Question: Where was a beer, wine and food festival held at prior to the Super Bowl?
# Predicted Answer: santa clara convention center
# Actual Answer: s
#
#
# Question: Who helped find sponsors and donors to help with the cost?
# Predicted Answer: the city council
# Actual Answer: a
#
#
# Question: Who set aside seed funding for the week-long event leading up to the Super Bowl?
# Predicted Answer: city council
# Actual Answer: c
#
#
# Question: Who may have been called upon to fund the festival associated with the Super Bowl in Santa Clara?
# Predicted Answer: city council
# Actual Answer: c
#
#
# Question: On what day was Super Bowl Opening Night held?
# Predicted Answer: tuesday
# Actual Answer: m
#
#
# Question: On what day does the Super Bowl media day traditionally take place?
# Predicted Answer: tuesday
# Actual Answer: t
#
#
# Question: What venue hosted Super Bowl Opening Night?
# Predicted Answer: sap center
# Actual Answer: s
#
#
# Question: In what city is SAP Center located?
# Predicted Answer: san jose
# Actual Answer: s
#
#
# Question: A replica of what landmark was present at Super Bowl Opening Night?
# Predicted Answer: golden gate bridge
# Actual Answer: t
#
#
# Question: As a norm, what day of the week is the traditional Media Day held prior to a Super Bowl?
# Predicted Answer: monday
# Actual Answer: t
#
#
# Question: What day of the week was Media Day held on for Super Bowl 50?
# Predicted Answer: tuesday
# Actual Answer: m
#
#
# Question: What was the name of the Media Day event for Super Bowl 50?
# Predicted Answer: super bowl opening night
# Actual Answer: s
#
#
# Question: What is the name of the property where the media event was held for Super Bowl 50?
# Predicted Answer: sap center
# Actual Answer: s
#
#
# Question: What city was the media event held for Super Bowl 50?
# Predicted Answer: san jose
# Actual Answer: s
#
#
# Question: When is the game's media day usually held?
# Predicted Answer: tuesday afternoon
# Actual Answer: t
#
#
# Question: What new name was given to the media day?
# Predicted Answer: super bowl opening night
# Actual Answer: s
#
#
# Question: Where was media day for Super Bowl 50 held?
# Predicted Answer: san jose
# Actual Answer: s
#
#
# Question: What replica was used for player introductions?
# Predicted Answer: golden gate bridge
# Actual Answer: t
#
#
# Question: What day was Super Bowl 50 media day switched to?
# Predicted Answer: monday
# Actual Answer: m
#
#
# Question: What was media day called for Super Bowl 50?
# Predicted Answer: super bowl opening night
# Actual Answer: s
#
#
# Question: Where was the new media day event for Super Bowl 50 held?
# Predicted Answer: san jose
# Actual Answer: s
#
#
# Question: What bridge had a model of it at the Super Bowl Opening Night?
# Predicted Answer: golden gate bridge
# Actual Answer: g
#
#
# Question: What is the name of the program that provides contracting work to local companies?
# Predicted Answer: super bowl program
# Actual Answer: b
#
#
# Question: What health company was a Super Bowl sponsor?
# Predicted Answer: dignity health
# Actual Answer: d
#
#
# Question: What petroleum company was a Super Bowl sponsor?
# Predicted Answer: apple google yahoo intel yeah chevron and dignity health
# Actual Answer: c
#
#
# Question: How did the committee raise the money?
# Predicted Answer: over forty million dollars three sponsors
# Actual Answer: s
#
#
# Question: What is the Super Bowl program called that gives local companies business opportunities for the Super Bowl?
# Predicted Answer: business connect
# Actual Answer: b
#
#
# Question: What is the name of the service that gets local businesses contract chances with the Super Bowl?
# Predicted Answer: connect the super bowl program
# Actual Answer: b
#
#
# Question: The Super Bowl 50 Host Committee said it would be the most what ever?
# Predicted Answer: giving
# Actual Answer: t
#
#
# Question: Who is the trophy given to the Super Bowl champion named for?
# Predicted Answer: vince lombardi
# Actual Answer: v
#
#
# Question: What is the name of the trophy given to anyone who plays on the winning team in a Super Bowl?
# Predicted Answer: vince lombardi
# Actual Answer: v
#
#
# Question: What will the number "50" be plated with?
# Predicted Answer: gold
# Actual Answer: g
#
#
# Question: What is the name of the trophy that all Super Bowl winners receive?
# Predicted Answer: vince lombardi
# Actual Answer: t
#
#
# Question: Who, with Jim Nantz, was a member of the game's lead broadcast team?
# Predicted Answer: phil simms
# Actual Answer: p
#
#
# Question: How many different TV networks are considered to be the principal partners, when it comes to broadcasting NFL events?
# Predicted Answer: three
# Actual Answer: t
#
#
# Question: Where was Tracy Wolfson announcing from during the Super Bowl 50 game?
# Predicted Answer: the sidelines
# Actual Answer: s
#
#
# Question: Where was Evan Washburn located while announcing during the game?
# Predicted Answer: the sidelines
# Actual Answer: s
#
#
# Question: How many broadcast television partners does the NFL have?
# Predicted Answer: three
# Actual Answer: t
#
#
# Question: What was put on pylons for Super Bowl 50?
# Predicted Answer: cameras and microphones
# Actual Answer: c
#
#
# Question: Who reported on the sideline for ESPN Deportes?
# Predicted Answer: john sutcliffe
# Actual Answer: j
#
#
# Question: Who provided Spanish-language commentary alongside Raul Allegre?
# Predicted Answer: john sutcliffe
# Actual Answer: a
#
#
# Question: In what language did ESPN Deportes broadcast the game?
# Predicted Answer: spanish
# Actual Answer: s
#
#
# Question: Which TV network broadcasted Super Bowl 50 in Spanish?
# Predicted Answer: fox cbs
# Actual Answer: c
#
#
# Question: Who was the sideline reporter for ESPN Deportes?
# Predicted Answer: john sutcliffe
# Actual Answer: j
#
#
# Question: Who was the ESPN Deportes sideline commentator for Super Bowl 50?
# Predicted Answer: john sutcliffe
# Actual Answer: j
#
#
# Question: What service did Verizon customers need to use to stream the game on their smartphones?
# Predicted Answer: nfl mobile
# Actual Answer: n
#
#
# Question: What app did viewers use to watch the game on their smartphones?
# Predicted Answer: sports calm
# Actual Answer: n
#
#
# Question: Which mobile service were Verizon customers able to watch Super Bowl 50 on their phones?
# Predicted Answer: nfl
# Actual Answer: n
#
#
# Question: What did CBS provide of the Super Bowl 50 broadcast for its website, some apps and media players?
# Predicted Answer: digital streams of the game via c b s sports calm an
# Actual Answer: d
#
#
# Question: What followed The Late Show with Stephen Colbert?
# Predicted Answer: following the game
# Actual Answer: l
#
#
# Question: What brand sponsored the "Crash the Super Bowl" contest?
# Predicted Answer: doritos
# Actual Answer: d
#
#
# Question: Which company held a contest whereupon contestants could enter for a chance to have their own commercial shown during Super Bowl 50?
# Predicted Answer: doritos
# Actual Answer: d
#
#
# Question: Which video gaming company debuted their ad for the first time during Super Bowl 50?
# Predicted Answer: nintendo in the pumpkin mine company
# Actual Answer: n
#
#
# Question: Which company has held contests for fans to  create their own ad for the company?
# Predicted Answer: doritos
# Actual Answer: d
#
#
# Question: What company was this the last Super Bowl they would let customers have an opportunity to get their own commercial ideas aired?
# Predicted Answer: doritos
# Actual Answer: d
#
#
# Question: What company won a free advertisement due to the QuickBooks contest?
# Predicted Answer: death wish coffee
# Actual Answer: d
#
#
# Question: Besides Death Wish Coffee, how many other competitors participated in the contest?
# Predicted Answer: nine
# Actual Answer: n
#
#
# Question: Which company won a contest to have their ad shown for free during Super Bowl 50?
# Predicted Answer: click book sponsored a small business again contest in which death wish coffee
# Actual Answer: d
#
#
# Question: How many other contestants did the company, that had their ad shown for free, beat out?
# Predicted Answer: nine
# Actual Answer: n
#
#
# Question: Which company had a commercial aired for free as a result of the Quickbooks contest?
# Predicted Answer: death wish coffee
# Actual Answer: d
#
#
# Question: How many companies were part of the Quickbooks contest?
# Predicted Answer: nine
# Actual Answer: t
#
#
# Question: Who won the competition to get a free Super Bowl commercial aired?
# Predicted Answer: death wish coffee
# Actual Answer: d
#
#
# Question: What Universal trailer debuted during the Super Bowl?
# Predicted Answer:
# Actual Answer: j
#
#
# Question: Along with 10 Cloverfield Lane, what Paramount trailer appeared during the Super Bowl?
# Predicted Answer: teenage mutant ninja turtles out of the shadows
# Actual Answer: t
#
#
# Question: What was the subtitle of the Independence Day movie that had a trailer during the Super Bowl?
# Predicted Answer: apocalypse
# Actual Answer: r
#
#
# Question: Paramount paid fo, 10 Cloverfield Lane and which other film trailer to be aired during the game?
# Predicted Answer: teenage mutant ninja turtles out of the shadows
# Actual Answer: t
#
#
# Question: Universal Paid for The Secret Life of Pets and which other film trailer?
# Predicted Answer: paxson
# Actual Answer: j
#
#
# Question: What famous July Fourth holiday movie did Fox pay to advertise a sequel of during the Super Bowl?
# Predicted Answer:
# Actual Answer: i
#
#
# Question: What movie company paid to have the next Jason Bourne movie ad shown during the Super Bowl?
# Predicted Answer: twentieth century fox l
# Actual Answer: u
#
#
# Question: What company paid for a Super Bowl 50 ad to show a trailer of X-Men: Apocalypse?
# Predicted Answer: twentieth century
# Actual Answer: f
#
#
# Question: What radio network carried the Super Bowl?
# Predicted Answer: westwood one
# Actual Answer: w
#
#
# Question: How many color analysts were involved with Super Bowl 50?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: Who will carry the game throughout all of North America?
# Predicted Answer: westwood one w
# Actual Answer: w
#
#
# Question: What did Jim Gray cover?
# Predicted Answer: westwood one will carry the game throughout north america with kevin harlin is play by play announcer bloomers science in and day and found this collar analysts in james loft in denmark malone is sideline reporters. jan gray will anchor the pre game at halftime coverage
# Actual Answer: h
#
#
# Question: What area did the Westwood One broadcast cover?
# Predicted Answer: westwood one will carry the game throughout north america
# Actual Answer: n
#
#
# Question: Who handled play-by-play for the Denver radio market?
# Predicted Answer: dave logan
# Actual Answer: d
#
#
# Question: In what city is WBT-FM located?
# Predicted Answer: chester south carolina
# Actual Answer: c
#
#
# Question: Who handled the play-by-play for the Denver radio stations?
# Predicted Answer: dave logan
# Actual Answer: d
#
#
# Question: Who handled the color commentary for Denver's radio stations?
# Predicted Answer: ed mccaffrey
# Actual Answer: e
#
#
# Question: British commentators include, Darren Fletcher, Rocky Boiman and who else?
# Predicted Answer: greg brady
# Actual Answer: g
#
#
# Question: Who was the Most Valuable Player of Super Bowl II?
# Predicted Answer: peyton manning
# Actual Answer: b
#
#
# Question: Who was the Most Valuable Player of Super Bowl XLI?
# Predicted Answer: peyton manning
# Actual Answer: p
#
#
# Question: Who is the present quarterback of the Broncos?
# Predicted Answer: peyton manning
# Actual Answer: p
#
#
# Question: What former MVP was shown in the locker room?
# Predicted Answer: peyton manning
# Actual Answer: p
#
#
# Question: Which MVP died in 2001?
# Predicted Answer:
# Actual Answer: h
#
#
# Question: Who was the MVP of Super Bowl I and II?
# Predicted Answer: peyton manning
# Actual Answer: b
#
#
# Question: Who was the MVP of Super Bowl XLI?
# Predicted Answer: peyton manning
# Actual Answer: p
#
#
# Question: Which MVP honoree died in 2001?
# Predicted Answer: peyton manning
# Actual Answer: h
#
#
# Question: How many Grammys has Lady Gaga won?
# Predicted Answer: six
# Actual Answer: s
#
#
# Question: What did Lady Gaga sing?
# Predicted Answer: the national anthem
# Actual Answer: t
#
#
# Question: What award has Marlee Matlin won?
# Predicted Answer: academy award
# Actual Answer: a
#
#
# Question: What did Marlee Matlin translate?
# Predicted Answer: american sign language
# Actual Answer: t
#
#
# Question: Into what language did Marlee Matlin translate the national anthem?
# Predicted Answer: american sign language
# Actual Answer: a
#
#
# Question: Who sang the national anthem?
# Predicted Answer: lady gaga
# Actual Answer: l
#
#
# Question: Who did the National Anthem at Super Bowl 50?
# Predicted Answer: lady gaga
# Actual Answer: l
#
#
# Question: Who did the Super Bowl 50 National Anthem?
# Predicted Answer: lady gaga
# Actual Answer: l
#
#
# Question: How many Grammy Award's does the text say Lady Gaga has won?
# Predicted Answer: six time grammy
# Actual Answer: s
#
#
# Question: What nationality is the band Coldplay?
# Predicted Answer: british
# Actual Answer: b
#
#
# Question: What company confirmed that Beyoncé would participate in the Super Bowl 50 halftime show?
# Predicted Answer: associated press
# Actual Answer: p
#
#
# Question: Which single did Beyoncé and Coldplay collaborate on?
# Predicted Answer: him for the weekend
# Actual Answer: m
#
#
# Question: What other former halftime show performer joined Coldplay and Beyoncé for the Super Bowl 50 halftime show?
# Predicted Answer: bruno mars
# Actual Answer: b
#
#
# Question: What team received the opening kickoff?
# Predicted Answer: denver to
# Actual Answer: d
#
#
# Question: Who was at the receiving end of a 22-yard pass from Peyton Manning?
# Predicted Answer: andre caldwell
# Actual Answer: a
#
#
# Question: Who ran the ball twice for 20 yards on this drive?
# Predicted Answer: peyton manning
# Actual Answer: a
#
#
# Question: Who tackled Ronnie Hillman for a loss of yardage?
# Predicted Answer: jack thompson
# Actual Answer: t
#
#
# Question: This was the first time that the Carolina team faced what in the post season?
# Predicted Answer: deficit
# Actual Answer: a
#
#
# Question: Which team had the first kickoff?
# Predicted Answer: denver to
# Actual Answer: d
#
#
# Question: Who did Peyton Manning complete an 18 yard pass to on the opening drive?
# Predicted Answer: andre caldwell
# Actual Answer: d
#
#
# ...
# Predicted Answer:
# Actual Answer: n
#
#
# Question: How are laboratory measurements of forces determined?
# Predicted Answer: since forces are perceive
# Actual Answer: e
#
#
# Question: What physical quantities do not have direction?
# Predicted Answer: t force
# Actual Answer: s
#
#
# Question: How do you avoid problems when determining forces involved on an object from two or more sources?
# Predicted Answer: is calling it is
# Actual Answer: k
#
#
# Question: If you do not know both magnitude and direction of two forces on an object, what would you call that situation?
# Predicted Answer: e rope will be. the
# Actual Answer: a
#
#
# Question: How do you determine the acceleration of a rope when two people are pulling it?
# Predicted Answer: g the pleasure
# Actual Answer: k
#
#
# Question: In what conditions were forces first measured historically?
# Predicted Answer: leling gr
# Actual Answer: s
#
#
# Question: What do forces have with regard to additive quantities?
# Predicted Answer:  the angle between their lin
# Actual Answer: m
#
#
# Question: What is the resultant force called when two forces act on a particle?
# Predicted Answer: historically forces were first quantitatively investigated in conditions of static equilibrium where several forces cancel each other out. such experiments demonstrate the crucial properties tha
# Actual Answer: n
#
#
# Question: When forces are acting on an extended body, what do you need to account for motion effects?
# Predicted Answer: es are added to ve
# Actual Answer: r
#
#
# Question: Whwn forces are at right ngles to each other what can they be broken down to?
# Predicted Answer: ing force facto
# Actual Answer: i
#
#
# Question: If a force is pointing horizontally to the northeast, how many forces can you split the force into?
# Predicted Answer: on of the comp
# Actual Answer: t
#
#
# Question: What do you get when you figure the sum of forces with vector addition?
# Predicted Answer: that force would then ha
# Actual Answer: t
#
#
# Question: What are the independant components of a vector sum that has been determined by scalar addition of individual vectors?
# Predicted Answer: as well as being added forces can also be resolved into independent components at right angles
# Actual Answer: u
#
#
# Question: What can keep an object from moving when it is being pushed on a surface?
# Predicted Answer: ases in response t
# Actual Answer: s
#
#
# Question: What is generated between a surface and an object that is being pushed?
# Predicted Answer: ases in response t
# Actual Answer: s
#
#
# Question: Static friction balances what force when there is no movement of an object on a surface?
# Predicted Answer:
# Actual Answer: a
#
#
# Question: What makes static friction go up or down in responce to contact characteristics between an object and the surface it is on?
# Predicted Answer: result i
# Actual Answer: a
#
#
# Question: What can scales and spring balances measure between two forces by using static equilibrium?
# Predicted Answer: ring balances
# Actual Answer: f
#
#
# Question: What force acts on an object suspended on a spring scale in addition to gravity?
# Predicted Answer: e and objects to spend it on a vertical spring scale
# Actual Answer: s
#
#
# Question: What equals the spring reaction force on an object suspended on a spring reaction scale?
# Predicted Answer: ring scale exp
# Actual Answer: g
#
#
# Question: Objects of constant density are proportional to volume by what force to define standard weights?.
# Predicted Answer: tatic equilibrium b
# Actual Answer: g
#
#
# Question: Who expounded the Three Laws of Motion?
# Predicted Answer: nia to define standard
# Actual Answer: i
#
#
# Question: Who first described dynamic equilibrium?
# Predicted Answer:  certain assumptions on
# Actual Answer: g
#
#
# Question: What does motion at a constant velocity equal?
# Predicted Answer:
# Actual Answer: r
#
#
# Question: Who had the idea of a natural state for objects at rest?
# Predicted Answer: owed that galileos
# Actual Answer: g
#
#
# Question: Where will a canonball dropped from the crow's nest of a ship land according to Aristotle?
# Predicted Answer: uivalent to rest. this
# Actual Answer: s
#
#
# Question: What occurs when traveling across a surface at a constant velocity with regard to friction?
# Predicted Answer: as simple case of dynami
# Actual Answer: d
#
#
# Question: What directly opposes the force applied to move an object across a surface?
# Predicted Answer:
# Actual Answer: k
#
#
# Question: What has to accounted for that causes no net force being the cause of constant velocity motion?
# Predicted Answer: tion.
# Actual Answer: k
#
#
# Question: Who thought that applied force caused movement of an object regardless of non-zero velocity?
# Predicted Answer:
# Actual Answer: a
#
#
# Question: What equation currently decribes the physics of force.
# Predicted Answer: aling with operato
# Actual Answer: n
#
#
# Question: What equation desribed the physics of force before the current Schrodinger equation?
# Predicted Answer: nsequence that the resu
# Actual Answer: n
#
#
# Question: How are the forces derived from fields treated similarly to?
# Predicted Answer:  is of co
# Actual Answer: c
#
#
# Question: What type of measurements result under Schrodinger equations when using operators instead of Newtonian variables?
# Predicted Answer:
# Actual Answer: o
#
#
# Question: What notion keeps it's meaning through both Netonian and Schrodinger physics equations?
# Predicted Answer: though one is now dealing with operato
# Actual Answer: f
#
#
# Question: What is the intrisic angular variable called when particles act upon one another?
# Predicted Answer: gul
# Actual Answer: s
#
#
# Question: What value does the seperating into fermions and bosons depend?
# Predicted Answer: ables. depending o
# Actual Answer: s
#
#
# Question: If the apparant force of two fermions is repulsive, what is the spin function?
# Predicted Answer: etric
# Actual Answer: p
#
#
# Question: How are the particle forces and accelerations explained as by gauge bosons exchange?
# Predicted Answer: oes on. with th
# Actual Answer: m
#
#
# Question: What is the redundant concept coming from momentum conservation?
# Predicted Answer: oes on. with th
# Actual Answer: f
#
#
# Question: What is more fundamental than force in quanton field theory?
# Predicted Answer: lativity and
# Actual Answer: c
#
#
# Question: What diagrams are used to simplify particle interactions on a fundamental level?
# Predicted Answer: of momentum c
# Actual Answer: f
#
#
# Question: Matter particles are shown as what kind of lines in a Feynman diagram?
# Predicted Answer: as realize that
# Actual Answer: s
#
#
# Question: How many interactions are all of the universal forces based on?
# Predicted Answer: including nuclear arms n compound nuclei. the electromagnetic force acts between electric char
# Actual Answer: f
#
#
# Question: What nuclear forces only act at short distances?
# Predicted Answer: including nuclea
# Actual Answer: s
#
#
# Question: What force acts between electric charges?
# Predicted Answer: including nuclea
# Actual Answer: e
#
#
# Question: What do gravitational forces act between?
# Predicted Answer: forces in th
# Actual Answer: m
#
#
# Question: Who formed the universal theory of gravitation?
# Predicted Answer:  forces
# Actual Answer: i
#
#
# Question: What kind of self-consistent models are physicists trying to make that would create a theory of everything?
# Predicted Answer: the development of fundamental theories for forces proceeded along the lines of unification of desperate ideas. for example isaac newton unified the force responsible for objects falling at the surface of the earth with the force responsible for the orbits of celestial mechanics in his universal theory of gravitation. michael fair day in james clark maxwell dem
# Actual Answer: u
#
#
# Question: Who identified gravity as a force?
# Predicted Answer: tant an i
# Actual Answer: i
#
#
# Question: Who came up with the concept that falling objects fell at the same speed regardless of weight?
# Predicted Answer:
# Actual Answer: g
#
#
# Question: Where was the measurment for the standard gravity on Earth taken?
# Predicted Answer: well we now call gravity w
# Actual Answer: s
#
#
# Question: What is an object's mass proportional to at the surface of the Earth?
# Predicted Answer: before noon in t
# Actual Answer: f
#
#
# Question: How might gravity effects be observed differently according to Newton?
# Predicted Answer:
# Actual Answer: a
#
#
# Question: What could be attributed to gravity acceleration around the Earth?
# Predicted Answer: al to the
# Actual Answer: f
#
#
# Question: What is gravitational acceleration proportional to?
# Predicted Answer: scribed to the same
# Actual Answer: m
#
#
# Question: What is included along with gravitational acceration, and mass of the Earth in a formula about rotation about the Earth?
# Predicted Answer: scribed to the same
# Actual Answer: r
#
#
# Question: Who made the first to measure value of the Newton Universal Gravitation Constant?
# Predicted Answer: t since all celestial bodies
# Actual Answer: h
#
#
# Question: Who figured out that his law of gravity had to be universal?
# Predicted Answer:
# Actual Answer: n
#
#
# Question: What planet seemed to buck Newton's gravitational laws?
# Predicted Answer: he was only
# Actual Answer: m
#
#
# Question: What theory accounted for the Mercury problem?
# Predicted Answer:  however
# Actual Answer: t
#
#
# Question: Who came up with the theory of relativity?
# Predicted Answer: predicted the existence of another planet balkan that would explain the discrepancies however despite some early indications no such plan it could be found. when albert einstein formulated hi
# Actual Answer: a
#
#
# Question: Who first showed that Newton's Theory of Gravity was not as correct as another theory?
# Predicted Answer:
# Actual Answer: a
#
#
# Question: What theory best explains gravity?
# Predicted Answer: gravitation is not v
# Actual Answer: g
#
#
# Question: What space-time path is seen as a curved line in space?
# Predicted Answer: ight l
# Actual Answer: b
#
#
# Question: What is the derivative of an object's changing momentum called?
# Predicted Answer: nd is the shortest space
# Actual Answer: g
#
#
# Question: In what sense must you be observing the curvature of space-time?
# Predicted Answer:
# Actual Answer: g
#
#
# Question: What is  the time rate of change of electric charge?
# Predicted Answer:
# Actual Answer: e
#
#
# Question: What magnetic and electric force acts on a charge?
# Predicted Answer: through combining the definition of electric current as the time rate of change of electric charge the role of vector multiplication called lorenz as la describes the force on a charge moving in a magnetic field. the connection between electricity and magnetism allows for the description of the unified electromagnetic force that acts on a charge. this force can be written as as some of the electrostatic force due to the e
# Actual Answer: u
#
#
# Question: Whatare the electrostatic and magnetic force awritten as the sum of?
# Predicted Answer: f electric charge the
# Actual Answer: e
#
#
# Question: Who first fully explained the origins of magnetic and electric fields?
# Predicted Answer:
# Actual Answer: j
#
#
# Question: Who discovered that magnetic and electric could self-generate?
# Predicted Answer: xwell equations
# Actual Answer: m
#
#
# Question: What was dificult to reconcile the photoelectric effect and the missing ultraviolet catastrophe?
# Predicted Answer:  of the ultr
# Actual Answer: e
#
#
# Question: What was used to create a new electromagnetic theory to reconcile the troubles with electromagnetic theory as it used to stand?
# Predicted Answer: antum mechanics. this final modification to electromagnetic theory ultimately lead to quantum elektra dynamics or huey d which fully described salleh dramatic next phenomena as being mediated by way of particles known as photons. aint you read the photons are the fundamental exchange particle which describe doll interactions relating to electromagnetic them including the electromagnetic force note fuller.
# Actual Answer: q
#
#
# Question: What are the wave-particles called that mediate all electromagnetic phenomena?
# Predicted Answer: oto electric
# Actual Answer: p
#
#
# Question: What is needed to pack electrons densely together?
# Predicted Answer: vity an
# Actual Answer: e
#
#
# Question: What is needed to pack electrons densely together?
# Predicted Answer: sted maka
# Actual Answer: e
#
#
# Question: What does stong force act upon?
# Predicted Answer:
# Actual Answer: e
#
#
# Question: What can be seen between hadrons?
# Predicted Answer: rces observed be
# Actual Answer: r
#
#
# Question: What is the force between nucleons?
# Predicted Answer:  force. here the strong f
# Actual Answer: n
#
#
# Question: What does the W and Z boson exchange create?
# Predicted Answer: been developed which shows
# Actual Answer: w
#
#
# Question: What is the repulsive force of close range atom interaction?
# Predicted Answer: he solid object. an exa
# Actual Answer: n
#
#
# Question: What is the force that causes rigid strength in structures?
# Predicted Answer: nterface betwee
# Actual Answer: n
#
#
# Question: What can be used to model tension forces?
# Predicted Answer:  in action reac
# Actual Answer: i
#
#
# Question: What is the final effect of adding more and more idea strings to a load?
# Predicted Answer: ideal s
# Actual Answer: c
#
#
# Question: What can increase the tension force on a load?
# Predicted Answer:  that are mast lids frictionless unbreakable and on stretch of all. they can be combined with ideal collies which allow ideal strings to switch physical direction. ideals strings transmit tension forces instantaneously in action reaction paris so that if two objects are connected by an ideal stir
# Actual Answer: e
#
#
# Question: What did Newton's mechanics affect?
# Predicted Answer: rts of an objec
# Actual Answer: i
#
#
# Question: In what kind of fluid are pressure differences caused by direction of forces over gradients?
# Predicted Answer: rts of an objec
# Actual Answer: e
#
#
# Question: What may a force on one part of an object affect?
# Predicted Answer: tonian mechanics i
# Actual Answer: o
#
#
# Question: What does matter actually have that Newtonian mechanics doesn't address?
# Predicted Answer: e gradient says fo
# Actual Answer: e
#
#
# Question: What includes pressure terms when calculating area in volume?
# Predicted Answer:
# Actual Answer: f
#
#
# Question: What is the force equivalent of torque compared to angular momentum?
# Predicted Answer: igid b
# Actual Answer: r
#
#
# Question: To calculate instant angular acceleration of a rigid body what would you use?
# Predicted Answer: torches the rotation equivalent of force in the same
# Actual Answer: n
#
#
# Question: Where does centripetal force go?
# Predicted Answer:
# Actual Answer: t
#
#
# Question: How do centripetal forces act in relation to vectors of velocity?
# Predicted Answer:
# Actual Answer: p
#
#
# Question: What is another word for centripetal force?
# Predicted Answer: ircular happened is
# Actual Answer: r
#
#
# Question: What is resposible for speeding up or slowing down an object?
# Predicted Answer: ircular happened is
# Actual Answer: t
#
#
# Question: What is the only form potential energy can change into?
# Predicted Answer: a conservative force that acts
# Actual Answer: k
#
#
# Question: What is the only form kinetic energy can change into?
# Predicted Answer: force therefore i
# Actual Answer: p
#
#
# Question: What is preserved in a closed system of forces when acted upon?
# Predicted Answer: f afloa
# Actual Answer: n
#
#
# Question: What is the force between two locations related to?
# Predicted Answer: map of
# Actual Answer: d
#
#
# Question: What is the force called rgarding a potential field between two locations?
# Predicted Answer: map of
# Actual Answer: a
#
#
# Question: What is sometimes impossible to model?
# Predicted Answer: ible to model forces
# Actual Answer: f
#
#
# Question: What do electrostatic gradiient potentials create?
# Predicted Answer: degrading enough poten
# Actual Answer: f
#
#
# Question: In what treatment are nonconservative and conservative forces described?
# Predicted Answer: ervative forces a
# Actual Answer: s
#
#
# Question: What changes macroscopic closed system energies?
# Predicted Answer: the connection between makar scott p
# Actual Answer: i
#
#
# Question: What is the law of thermodynamics associated with closed system heat exchange?
# Predicted Answer: the connection betwee
# Actual Answer: s

# %% [markdown]
# ## F1 Score

# %%
from sklearn.metrics import f1_score
from collections import Counter

# %%
def f1_score_based_on_tokens(predictions, actuals):
    def f1_score_single(pred, actual):
        if pred == "":
            return 0 if actual else 1
        pred_tokens = pred.split()
        actual_tokens = actual.split()
        
        common = Counter(pred_tokens) & Counter(actual_tokens)
        num_same = sum(common.values())
        
        if num_same == 0:
            return 0
        
        precision = num_same / len(pred_tokens)
        recall = num_same / len(actual_tokens)
        
        return (2 * precision * recall) / (precision + recall)
    
    f1_scores = [f1_score_single(pred, actual) for pred, actual in zip(predictions, actuals)]
    return sum(f1_scores) / len(f1_scores)  # Average F1 score

# %%
predicted_answers = []
actual_answers = []

for i, example in enumerate(dataset):
    actual_answer = example["answers"]["text"][0] 
    offset_mapping = tokenized_eval[i]["offset_mapping"]
    predicted_answer = get_predicted_answers(
        example["context"], offset_mapping, start_logits[i], end_logits[i]
    )

    predicted_answers.append(predicted_answer)
    actual_answers.append(actual_answer)

# %%
f1 = f1_score_based_on_tokens(predicted_answers, actual_answers)
print(f"F1 Score: {f1 * 100:.2f}")
# Out:
# F1 Score: 0.73
